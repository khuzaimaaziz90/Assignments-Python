# %% [markdown]
# # Assigment no 6

# %% [markdown]
# Question No.1: Define Object Oriented Programming Language?
#
# Ans: OOP is a methodology that provides multiple concepts such as (Inheritance,Polymorphism, Encapsulation etc).
# OBJECT is an entity that can be tengible intengible, ORIENTATION means Function of Mind eg: Way to think or analyze Something
#
# Question No.2: List down the Benefits of OOP?
# Ans:
# OOP provides a clear modular structure for programs.
# it good for defining abstract data types
# Implementation details are hidden from other modules
# It is easy to maintain modify existing code.
# It imlements real life scenario.
#
# Question No.3: Differentiate between function and method?
# Ans:
# Functions: Function can be defined outside as well it can be used as a single body in program.
#
# Methods: Functions in the class having diferent functionalities and features within the class are basically Methods
#
# Queation No.4: Define the following terms:
# Class,
# Object,,
# Attribute,
# Behavior.
# Ans: Class:: It is the template, blue print or the capability of what an oblect can do. Object:: It is the Instance of class, if a class is defined there is no memory or stoage is allowcated. Attribute :: The physiacal appearance and look of code/program. Behavior:: Specific Functionalities and Operations that a mehtod can perform.

# %%
#Question no. 6

class car():
    
    def __init__(self,name,model,color):
        self.name = name
        self.model = model
        self.color = color
        self.price = '2 Million'
        self.country = 'Japan'
        
        
    def updatecarname(self,newname):
        self.name = newname
    
    
    def updatecolor(self,newcolor):
        self.color = newcolor
    
    
    def updatecountry(self,countryname):
        self.country = countryname
        
        
        
car_1 = car('toyota',2019,'red')    
print(car_1.name)
car_1.updatecarname('Volkswagen')
print(car_1.name,',updated name')
print(car_1.model,'Model')
print(car_1.color)
car_1.updatecolor('Green')
print(car_1.color,',Updated color')
print(car_1.price,'Rupees')
print(car_1.country)
car_1.updatecountry('Germany')
print(car_1.country,',updated country name')

    
    
print('============================================================================')    
car_2 = car('suzuki',2018,'yellow')    
print(car_2.name)
car_2.updatecarname('Maruti')
print(car_2.name,',updated name')
print(car_2.model,'Model')
print(car_2.color)
car_2.updatecolor('red')
print(car_2.color,',Updated color')
print(car_2.price,'Rupees')
print(car_2.country)
car_2.updatecountry('India')
print(car_2.country,',updated country name')


print('==============================================================================')

car_3 = car('Civic',2016,'grey')    
print(car_3.name)
car_3.updatecarname('cultus')
print(car_3.name,',updated name')
print(car_3.model,'Model')
print(car_3.color)
car_3.updatecolor('yellow')
print(car_3.color,',Updated color')
print(car_3.price,'Rupees')
print(car_3.country)
car_3.updatecountry('Pakistan')
print(car_3.country,',,updated country name')


print('================================================================================')
car_4 = car('mehran',2017,'yellow')    
print(car_4.name)
car_4.updatecarname('Lamborghini')
print(car_4.name,',updated name')
print(car_4.model,'Model')
print(car_4.color)
car_4.updatecolor('black')
print(car_4.color,',Updated color')
print(car_4.price,'Rupees')
print(car_4.country)
car_4.updatecountry('USA')
print(car_4.country,',updated country name')



print('===================================================================================')
car_5 = car('Ferrari',2020,'black')    
print(car_5.name)
car_5.updatecarname('Tesla')
print(car_5.name,',updated name')
print(car_5.model,'Model')
print(car_5.color)
car_5.updatecolor('Golden')
print(car_5.color,',Updated color')
print(car_5.price,'Rupees')
print(car_5.country)
car_5.updatecountry('USA')
print(car_5.country,',updated country name')
# Out:
# toyota
# Volkswagen ,updated name
# 2019 Model
# red
# Green ,Updated color
# 2 Million Rupees
# Japan
# Germany ,updated country name
# ...
# suzuki
# Maruti ,updated name
# 2018 Model
# yellow
# red ,Updated color
# 2 Million Rupees
# Japan
# India ,updated country name
# ...
# Civic
# cultus ,updated name
# 2016 Model
# grey
# yellow ,Updated color
# 2 Million Rupees
# Japan
# Pakistan ,,updated country name
# ...
# mehran
# Lamborghini ,updated name
# 2017 Model
# yellow
# black ,Updated color
# 2 Million Rupees
# Japan
# USA ,updated country name
# ...
# Ferrari
# Tesla ,updated name
# 2020 Model
# black
# Golden ,Updated color
# 2 Million Rupees
# Japan
# USA ,updated country name
